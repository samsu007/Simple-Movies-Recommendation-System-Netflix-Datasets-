# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head(10)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
# 9  70304990    Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 8                              NaN
# 9                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 5  Alberto Ammann, Eloy Azorín, Verónica Echegui,...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 8                                                NaN
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
#                                           country         date_added  \
# 0        United States, India, South Korea, China  September 9, 2019
# 1                                  United Kingdom  September 9, 2016
# 2                                   United States  September 8, 2018
# 3                                   United States  September 8, 2018
# 4                                   United States  September 8, 2017
# 5                                           Spain  September 8, 2017
# 6          Bulgaria, United States, Spain, Canada  September 8, 2017
# 7                                           Chile  September 8, 2017
# 8                                   United States  September 8, 2017
# 9  United States, United Kingdom, Denmark, Sweden  September 8, 2017
#
#    release_year    rating  duration  \
# 0          2019     TV-PG    90 min
# 1          2016     TV-MA    94 min
# 2          2013  TV-Y7-FV  1 Season
# 3          2016     TV-Y7  1 Season
# 4          2017     TV-14    99 min
# 5          2016     TV-MA  1 Season
# 6          2014         R   110 min
# 7          2017     TV-MA    60 min
# 8          2017     TV-MA  1 Season
# 9          2014         R    90 min
#
#                                            listed_in  \
# 0                 Children & Family Movies, Comedies
# 1                                    Stand-Up Comedy
# 2                                           Kids' TV
# 3                                           Kids' TV
# 4                                           Comedies
# 5  Crime TV Shows, International TV Shows, Spanis...
# 6  International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                    Stand-Up Comedy
# 8                    Docuseries, Science & Nature TV
# 9                      Action & Adventure, Thrillers
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...
# 5  A young journalist is forced into a life of cr...
# 6  In a dystopian future, an insurance adjuster f...
# 7  Fabrizio Copano takes audience participation t...
# 8  As California's 2016 fire season rages, brave ...
# 9  A struggling couple can't believe their luck w...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
# show_id         6234 non-null int64
# type            6234 non-null object
# title           6234 non-null object
# director        4265 non-null object
# cast            5664 non-null object
# country         5758 non-null object
# date_added      6223 non-null object
# release_year    6234 non-null int64
# rating          6224 non-null object
# duration        6234 non-null object
# listed_in       6234 non-null object
# description     6234 non-null object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
features = ['description','cast','listed_in','director']

# %%
for feature in features:
    df[feature] = df[feature].fillna('unknown')

# %%
def combine_features(row):
    try:
        return(row['cast'] + " " + row['listed_in'] + " " + row['director'])
    except:
        return row

# %%
df['combine_features'] = df.apply(combine_features,axis=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(df['combine_features'])

# %%
similarity_scores = cosine_similarity(count_matrix)

# %%
# df.set_index('show_id')
# df.reset_index()

# %%
def get_index_from_title(title):
    return df[df.title == title]['index'].values[0]

def get_title_from_index(index):
    return df[df.index == index]['title'].values[0]


movies_user_likes = "Transformers Prime"
movie_index = get_index_from_title(movies_user_likes)
lists = list(enumerate(similarity_scores[movie_index]))
similar_movies = sorted(lists,key=lambda x:x[1],reverse=True)

i=0
for movie in similar_movies:
    print(get_title_from_index(movie[0]))
    i= i + 1
    if i > 10:
        break
# Out:
#    level_0  index   show_id     type               title director  \
# 2        2      2  70234439  TV Show  Transformers Prime  unknown
#
#                                                 cast        country  \
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
#
#           date_added  release_year    rating  duration listed_in  \
# 2  September 8, 2018          2013  TV-Y7-FV  1 Season  Kids' TV
#
#                                          description  \
# 2  With the help of three human allies, the Autob...
#
#                                     combine_features
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# None
#       level_0  index   show_id     type                         title  \
# 1786     1786   1786  80174364  TV Show  All Hail King Julien: Exiled
#
#      director                                               cast  \
# 1786  unknown  Danny Jacobs, Andy Richter, Kevin Michael Rich...
#
#             country    date_added  release_year    rating  duration  \
# 1786  United States  May 12, 2017          2017  TV-Y7-FV  1 Season
#
#                                          listed_in  \
# 1786  Kids' TV, TV Action & Adventure, TV Comedies
#
#                                             description  \
# 1786  Julien's been dethroned, but loyal friends and...
#
#                                        combine_features
# 1786  Danny Jacobs, Andy Richter, Kevin Michael Rich...
# None
#       level_0  index   show_id     type              title director  \
# 6061     6061   6061  70180088  TV Show  The Garfield Show  unknown
#
#                                            cast                country  \
# 6061  Frank Welker, Wally Wingert, Gregg Berger  France, United States
#
#              date_added  release_year rating   duration  \
# 6061   February 1, 2019          2018  TV-Y7  3 Seasons
#
#                   listed_in  \
# 6061  Kids' TV, TV Comedies
#
#                                             description  \
# 6061  Lazy, lasagna-loving fat cat Garfield lives li...
#
#                                        combine_features
# 6061  Frank Welker, Wally Wingert, Gregg Berger Kids...
# None
#      level_0  index   show_id     type  \
# 307      307    307  81073764  TV Show
#
#                                                 title director     cast  \
# 307  Loo Loo Kids: Johny & Friends Musical Adventures  unknown  unknown
#
#     country         date_added  release_year rating  duration listed_in  \
# 307     NaN  September 1, 2019          2016   TV-Y  1 Season  Kids' TV
#
#                                            description  \
# 307  Music-loving baby Johny goes on dance-filled a...
#
#              combine_features
# 307  unknown Kids' TV unknown
# None
#      level_0  index   show_id     type                   title director  \
# 974      974    974  80097248  TV Show  Masha's Spooky Stories  unknown
#
#         cast                country       date_added  release_year rating  \
# 974  unknown  United States, Russia  October 1, 2016          2012   TV-Y
#
#      duration listed_in                                        description  \
# 974  1 Season  Kids' TV  Masha explains why there's no need to be scare...
#
#              combine_features
# 974  unknown Kids' TV unknown
# None
#       level_0  index   show_id     type          title director     cast  \
# 1300     1300   1300  80202454  TV Show  Chuck Chicken  unknown  unknown
#
#        country         date_added  release_year rating  duration listed_in  \
# 1300  Malaysia  November 15, 2017          2017  TV-Y7  1 Season  Kids' TV
#
#                                             description  \
# 1300  On the island of Rocky Perch, security company...
#
#               combine_features
# 1300  unknown Kids' TV unknown
# None
#       level_0  index   show_id     type  \
# 1995     1995   1995  80232149  TV Show
#
#                                                   title director     cast  \
# 1995  Bure Kaam Bura Natija, Kyun Bhai Chacha Haan B...  unknown  unknown
#
#      country      date_added  release_year rating  duration listed_in  \
# 1995     NaN  March 31, 2018          2017  TV-Y7  1 Season  Kids' TV
#
#                                             description  \
# 1995  A clever uncle-nephew duo solves mysteries, cr...
#
#               combine_features
# 1995  unknown Kids' TV unknown
# None
#       level_0  index   show_id     type          title director     cast  \
# 2225     2225   2225  70230417  TV Show  Oscar's Oasis  unknown  unknown
#
#      country      date_added  release_year rating  duration listed_in  \
# 2225  France  March 15, 2015          2011   TV-G  1 Season  Kids' TV
#
#                                             description  \
# 2225  Plucky lizard Oscar spends his time trying to ...
#
#               combine_features
# 2225  unknown Kids' TV unknown
# None
#       level_0  index   show_id     type          title director     cast  \
# 4083     4083   4083  80093829  TV Show  Masha's Tales  unknown  unknown
#
#      country        date_added  release_year rating  duration listed_in  \
# 4083     NaN  February 1, 2016          2012   TV-Y  1 Season  Kids' TV
#
#                                             description  \
# 4083  Fairy tales get a funny twist when Masha retel...
#
#               combine_features
# 4083  unknown Kids' TV unknown
# None
#       level_0  index   show_id     type         title director     cast  \
# 4698     4698   4698  70286809  TV Show  Zig & Sharko  unknown  unknown
#
#      country        date_added  release_year rating  duration listed_in  \
# 4698  France  December 1, 2017          2016   TV-Y  1 Season  Kids' TV
#
#                                             description  \
# 4698  Zig, an island-bound hyena, will do anything t...
#
#               combine_features
# 4698  unknown Kids' TV unknown
# None
#       level_0  index   show_id     type       title director     cast country  \
# 5478     5478   5478  81072430  TV Show  JingleKids  unknown  unknown     NaN
#
#          date_added  release_year rating  duration listed_in  \
# 5478  April 1, 2019          2017  TV-Y7  1 Season  Kids' TV
#
#                                             description  \
# 5478  In a magical wonderland, merry children and th...
#
#               combine_features
# 5478  unknown Kids' TV unknown
# None
